# %% [markdown]
# Visualizing Locations

# %%
# !pwd
# !ls -la
# Out:
# /Users/pedrohserrano/data-visualization/gmail-inbox-analysis
# total 2931720
# drwxr-xr-x  19 pedrohserrano  staff        646 Mar 11 20:20 .
# drwxr-xr-x  15 pedrohserrano  staff        510 Mar 11 02:12 ..
# -rw-r--r--@  1 pedrohserrano  staff       6148 Mar 11 20:20 .DS_Store
# drwxr-xr-x   5 pedrohserrano  staff        170 Mar 11 18:44 .ipynb_checkpoints
# -rwxr-xr-x@  1 pedrohserrano  staff   26216300 Feb 18 18:49 Destacados.mbox
# -rwxr-xr-x@  1 pedrohserrano  staff  966818573 Feb 18 18:49 Enviados.mbox
# -rwxr-xr-x@  1 pedrohserrano  staff   19843556 Feb 18 17:21 Historialdeubicaciones.json
# -rw-r--r--   1 pedrohserrano  staff      46529 Mar 11 19:46 Location.ipynb
# -rwxr-xr-x@  1 pedrohserrano  staff  486344978 Feb 18 18:51 Recibidos.mbox
# drwxr-xr-x@  4 pedrohserrano  staff        136 Jul 10  2005 demo
# drwx------@  8 pedrohserrano  staff        272 Mar 11 19:48 descartes-0-7
# -rwxr-xr-x@  1 pedrohserrano  staff     124415 Jul 10  2005 descartes.py
# -rwxr-xr-x@  1 pedrohserrano  staff     123939 Jul 10  2005 descartes.py~
# -rw-r--r--   1 pedrohserrano  staff     315510 Mar 11 02:07 gmail-inbox-analysis-berkeley.ipynb
# -rw-r--r--   1 pedrohserrano  staff     544189 Mar 11 02:26 gmail-inbox-analysis-test.ipynb
# -rw-r--r--   1 pedrohserrano  staff     573704 Mar 11 02:10 gmail-inbox-analysis.ipynb
# drwxr-xr-x  13 pedrohserrano  staff        442 Mar 11 02:16 images
# drwxr-xr-x@  3 pedrohserrano  staff        102 Jul 10  2005 plugin
# -rw-r--r--@  1 pedrohserrano  staff      54121 Jul 10  2005 rene.jpg

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
from shapely.prepared import prep
import fiona
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-a60ad5ab2442> in <module>()
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5 from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
#       6 from shapely.prepared import prep
#
# ImportError: No module named 'mpl_toolkits.basemap'

# %%
from descartes import PolygonPatch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-30669f9a7e1f> in <module>()
# ----> 1 from descartes import PolygonPatch
#
# ImportError: No module named 'descartes'

# %%
import matplotlib.pyplot

# %%
from mpl_toolkits.basemap
# Out:
#   File "<ipython-input-14-59b04a43a024>", line 1
#     from mpl_toolkits.basemap
#                              ^
# SyntaxError: invalid syntax

# %%
import sys
print(sys.version)
# Out:
# 3.5.3 |Anaconda 4.2.0 (x86_64)| (default, Mar  6 2017, 12:15:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon

# %%
import json
import datetime
with open('Historialdeubicaciones.json', 'r') as fh:
    raw = json.loads(fh.read())

ld = pd.DataFrame(raw['locations'])
del raw #free up some memory
# convert to typical units
ld['latitudeE7'] = ld['latitudeE7']/float(1e7) 
ld['longitudeE7'] = ld['longitudeE7']/float(1e7)
ld['timestampMs'] = ld['timestampMs'].map(lambda x: float(x)/1000) #to seconds
ld['datetime'] = ld.timestampMs.map(datetime.datetime.fromtimestamp)
# Rename fields based on the conversions we just did
ld.rename(columns={'latitudeE7':'latitude', 'longitudeE7':'longitude', 'timestampMs':'timestamp'}, inplace=True)
ld = ld[ld.accuracy < 1000] #Ignore locations with accuracy estimates over 1000m
ld.reset_index(drop=True, inplace=True)

# %%
ld
# Out:
#        accuracy                                          activitys  altitude  \
# 0            53                                                NaN       NaN
# 1            58                                                NaN       NaN
# 2            67                                                NaN       NaN
# 3            66  [{'timestampMs': '1414819919727', 'activities'...       NaN
# 4            55                                                NaN       NaN
# 5            57  [{'timestampMs': '1414819830517', 'activities'...       NaN
# 6            56  [{'timestampMs': '1414819770596', 'activities'...       NaN
# 7            30                                                NaN       NaN
# 8            55  [{'timestampMs': '1414819627104', 'activities'...       NaN
# 9            58  [{'timestampMs': '1414819474818', 'activities'...       NaN
# 10          118                                                NaN       NaN
# 11           54  [{'timestampMs': '1414819414877', 'activities'...       NaN
# 12           68                                                NaN       NaN
# 13           88  [{'timestampMs': '1414819316362', 'activities'...       NaN
# 14           24  [{'timestampMs': '1414819256433', 'activities'...       NaN
# 15           49  [{'timestampMs': '1414819136573', 'activities'...       NaN
# 16           49                                                NaN       NaN
# 17           49  [{'timestampMs': '1414819019700', 'activities'...       NaN
# 18           49  [{'timestampMs': '1414818942605', 'activities'...       NaN
# 19           47  [{'timestampMs': '1414818829573', 'activities'...       NaN
# 20           52                                                NaN       NaN
# 21           34                                                NaN       NaN
# 22           49  [{'timestampMs': '1414818745360', 'activities'...       NaN
# 23           37  [{'timestampMs': '1414818569561', 'activities'...       NaN
# 24           51                                                NaN       NaN
# 25           40  [{'timestampMs': '1414818434615', 'activities'...       NaN
# 26           36  [{'timestampMs': '1414818281608', 'activities'...       NaN
# 27           56                                                NaN       NaN
# 28           57  [{'timestampMs': '1414818132870', 'activities'...       NaN
# 29           40  [{'timestampMs': '1414818013019', 'activities'...       NaN
# ...         ...                                                ...       ...
# 63067        30                                                NaN       NaN
# 63068        22                                                NaN       NaN
# 63069        22  [{'timestampMs': '1390282804101', 'activities'...       NaN
# 63070        30                                                NaN       NaN
# 63071        30                                                NaN       NaN
# 63072        21                                                NaN       NaN
# 63073        26  [{'timestampMs': '1390282439285', 'activities'...       NaN
# 63074        30                                                NaN       NaN
# 63075        30                                                NaN       NaN
# 63076        30  [{'timestampMs': '1390282257902', 'activities'...       NaN
# 63077        30                                                NaN       NaN
# 63078        30                                                NaN       NaN
# 63079        23  [{'timestampMs': '1390282076410', 'activities'...       NaN
# 63080        22                                                NaN       NaN
# 63081        22                                                NaN       NaN
# 63082        30  [{'timestampMs': '1390281919874', 'activities'...       NaN
# 63083        20                                                NaN       NaN
# 63084        22                                                NaN       NaN
# 63085         5  [{'timestampMs': '1390268489754', 'activities'...    2220.0
# 63086        34                                                NaN       NaN
# 63087        32  [{'timestampMs': '1390268337045', 'activities'...       NaN
# 63088       100  [{'timestampMs': '1390268178023', 'activities'...       NaN
# 63089       100                                                NaN       NaN
# 63090       100  [{'timestampMs': '1390268031209', 'activities'...       NaN
# 63091        12  [{'timestampMs': '1390267962172', 'activities'...    2234.0
